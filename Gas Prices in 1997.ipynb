# %%
import pandas as pd

# %%
file_path = 'C:/Users/Bubi/Desktop/monthly_csv.csv'
file = pd.read_csv(file_path)

# %%
df = pd.DataFrame(file)
df.head(11)
# Out:
#       Month  Price
# 0   1997-01   3.45
# 1   1997-02   2.15
# 2   1997-03   1.89
# 3   1997-04   2.03
# 4   1997-05   2.25
# 5   1997-06   2.20
# 6   1997-07   2.19
# 7   1997-08   2.49
# 8   1997-09   2.88
# 9   1997-10   3.07
# 10  1997-11   3.01

# %%
df.sort_values(['Price'], ascending=True)
# Out:
#        Month  Price
# 281  2020-06   1.63
# 23   1998-12   1.72
# 230  2016-03   1.73
# 279  2020-04   1.74
# 280  2020-05   1.75
# ..       ...    ...
# 136  2008-05  11.27
# 104  2005-09  11.75
# 137  2008-06  12.69
# 107  2005-12  13.05
# 105  2005-10  13.42
#
# [284 rows x 2 columns]

# %%
df.loc[df['Price'] < 3]
# Out:
#        Month  Price
# 1    1997-02   2.15
# 2    1997-03   1.89
# 3    1997-04   2.03
# 4    1997-05   2.25
# 5    1997-06   2.20
# ..       ...    ...
# 279  2020-04   1.74
# 280  2020-05   1.75
# 281  2020-06   1.63
# 282  2020-07   1.77
# 283  2020-08   2.30
#
# [111 rows x 2 columns]

# %%
df.describe()
# Out:
#             Price
# count  284.000000
# mean     4.207782
# std      2.183396
# min      1.630000
# 25%      2.660000
# 50%      3.560000
# 75%      5.327500
# max     13.420000

# %%
plt.figure(figsize = (15,3), dpi = 100)

plt.xlabel('Months in 1997')
plt.ylabel('Gas prices')

x = np.array(df['Price'][:12])
y = np.array(df['Month'][:12])

plt.bar(y,x)
plt.show()

# %%
df.to_excel('modified.xlsx', index=False)
